# %% [markdown]
# # Baseline Classification Model: Random Forest w/ Feature Engineering

# %% [markdown]
# This file is composed of a random forest classification model to evaluate a general accuracy level of traditional ML methods in classifying our HAR data based on activity. We also used Leave-One-Out Cross-Validation to validate our models.

# %% [markdown]
# __INPUT: .csv files containing the sliding window summary statistics data with feature engineering (engineered_features.csv)__

# %% [markdown]
# __OUTPUT: Random Forest Multi-Classification Model__

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import seaborn as sns

# %% [markdown]
# ## Read in Data

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('../../10_code/40_usable_data_for_models/41_Duke_Data/engineered_features.csv')

# %%
df.head()
# Out:
#                                                 ACC1  \
# 0  [41.0 41.0 41.0 41.0 41.0 41.0 41.0 41.0 41.0 ...
# 1  [39.0 39.06521739130435 39.130434782608695 39....
# 2  [41.60869565217392 41.67391304347826 41.739130...
# 3  [43.971428571428575 44.14285714285715 44.31428...
# 4  [45.54838709677418 45.564516129032256 45.58064...
#
#                                                 ACC2  \
# 0  [27.2 27.3 27.4 27.5 27.6 27.7 27.8 27.9 28.0 ...
# 1  [29.0 28.93478260869565 28.869565217391305 28....
# 2  [26.39130434782609 26.32608695652174 26.260869...
# 3  [24.514285714285712 24.42857142857143 24.34285...
# 4  [25.64516129032258 25.69354838709677 25.741935...
#
#                                                 ACC3  \
# 0  [40.0 40.0 40.0 40.0 40.0 40.0 40.0 40.0 40.0 ...
# 1  [38.0 38.02173913043478 38.04347826086956 38.0...
# 2  [38.869565217391305 38.89130434782609 38.91304...
# 3  [37.17142857142857 37.142857142857146 37.11428...
# 4  [37.0 37.0 37.0 37.0 37.0 37.0 37.0 37.0 37.0 ...
#
#                                                 TEMP  \
# 0  [32.39 32.39 32.39 32.39 32.34 32.34 32.34 32....
# 1  [32.34 32.34 32.34 32.34 32.33 32.33 32.33 32....
# 2  [32.34 32.34 32.34 32.34 32.33 32.33 32.33 32....
# 3  [32.33 32.33 32.33 32.33 32.34 32.34 32.34 32....
# 4  [32.34 32.34 32.34 32.34 32.33 32.33 32.33 32....
#
#                                                  EDA  \
# 0  [0.275354 0.276634 0.270231 0.270231 0.26895 0...
# 1  [0.25998499999999997 0.25998499999999997 0.258...
# 2  [0.265108 0.263827 0.266389 0.265108 0.266389 ...
# 3  [0.258704 0.258704 0.258704 0.257424 0.257424 ...
# 4  [0.253581 0.253581 0.253581 0.252301 0.252301 ...
#
#                                                  BVP  \
# 0  [15.25 -12.75 -42.99 18.39 13.61 -9.66 -35.47 ...
# 1  [-18.83 -0.3 11.03 6.09 -15.3 14.61 6.75 -2.38...
# 2  [-27.69 30.51 14.64 1.97 -13.65 -48.52 17.77 2...
# 3  [17.18 2.41 -22.11 5.12 18.43 5.34 -14.33 -22....
# 4  [-32.0 15.14 24.41 3.88 -22.97 -0.34 17.89 3.0...
#
#                                                   HR  \
# 0  [78.98 78.83500000000002 78.69 78.545 78.4 78....
# 1  [73.52 73.435 73.35 73.265 73.18 73.0925 73.00...
# 2  [69.63 69.515 69.4 69.285 69.17 69.04 68.91 68...
# 3  [64.68 64.555 64.43 64.305 64.18 64.0475 63.91...
# 4  [60.92 60.8475 60.77500000000001 60.7025 60.63...
#
#                                            Magnitude Subject_ID  Activity  \
# 0  [63.410093833710725 63.453053512025726 63.4961...     19-001  Baseline
# 1  [61.69278726074872 61.7168170027034 61.7409828...     19-001  Baseline
# 2  [62.758486272725364 62.78782873035957 62.81730...     19-001  Baseline
# 3  [62.579164557660036 62.649331804179724 62.7200...     19-001  Baseline
# 4  [64.04162603123257 64.07248675362091 64.103373...     19-001  Baseline
#
#    Round  ACC1_mean  ACC2_mean  ACC3_mean  TEMP_mean  EDA_mean  BVP_mean  \
# 0      1  40.248370  28.012880  38.824457     32.350  0.262354 -0.109875
# 1      1  40.820000  26.815000  38.192500     32.339  0.261058  0.321375
# 2      1  43.252235  25.312684  37.488043     32.337  0.259585  0.684000
# 3      1  44.905798  24.915984  37.638218     32.356  0.254510 -0.180875
# 4      1  43.577055  22.974382  38.971144     32.389  0.252733 -0.209750
#
#      HR_mean  Magnitude_mean  ACC1_std  ACC2_std  ACC3_std  TEMP_std  \
# 0  73.931187       62.553853  0.701573  0.687590  0.632616  0.017607
# 1  69.481750       62.021872  1.192214  1.149559  0.529382  0.012610
# 2  64.893188       62.621785  2.109896  0.815025  0.647914  0.010536
# 3  61.157687       63.734171  1.832017  1.509593  1.773398  0.025377
# 4  59.226438       62.913435  2.115371  2.585687  1.809092  0.027000
#
#     EDA_std    BVP_std    HR_std  Magnitude_std  ACC1_skew  ACC2_skew  \
# 0  0.004877  18.439453  2.574676       0.609756  -0.082592  -0.558848
# 1  0.003007  20.104717  2.608254       0.542348   0.515544   0.109446
# 2  0.004337  23.756276  2.639037       0.942868  -0.473020   0.227966
# 3  0.002396  25.635645  1.674001       0.841361  -4.941414  -1.040349
# 4  0.002055  25.593597  0.684349       1.365652  -1.857224   0.511935
#
#    ACC3_skew  TEMP_skew  EDA_skew  BVP_skew   HR_skew  Magnitude_skew  \
# 0   0.705668   0.714533  0.896382 -0.392823  0.296262        0.531557
# 1  -0.188071   0.787066  0.212943 -0.322900 -0.170923       -0.438037
# 2   1.329886   0.620801  0.072564 -0.274279  0.185657       -0.382833
# 3   3.435987   0.672586  0.734482 -0.828441  0.406263       -0.532117
# 4   1.380509  -0.686481  1.239716 -0.833856  0.996232        0.408229
#
#    ACC1_min   ACC2_min  ACC3_min  TEMP_min   EDA_min  BVP_min   HR_min  \
# 0      39.0  26.456522      38.0     32.33  0.254862   -42.99  69.7650
# 1      39.0  24.600000      37.2     32.31  0.254862   -48.52  64.8025
# 2      39.0  24.000000      37.0     32.31  0.252301   -48.52  60.9950
# 3      32.0  20.985816      37.0     32.33  0.251020  -101.74  58.8025
# 4      32.0  20.702128      37.0     32.33  0.249739  -101.74  58.5300
#
#    Magnitude_min   ACC1_max  ACC2_max  ACC3_max  TEMP_max   EDA_max  BVP_max  \
# 0      61.692787  41.543478      29.0      40.0     32.39  0.276634    34.83
# 1      60.778286  43.800000      29.0      39.0     32.37  0.266389    37.72
# 2      60.778286  45.532258      27.0      39.0     32.37  0.266389    47.14
# 3      61.392182  46.000000      27.0      48.0     32.41  0.262546    47.14
# 4      61.392182  46.000000      27.0      48.0     32.43  0.258704    39.00
#
#    HR_max  Magnitude_max
# 0   78.98      63.757353
# 1   73.52      62.936476
# 2   69.63      64.010791
# 3   64.68      65.711491
# 4   60.92      65.711491

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6572 entries, 0 to 6571
# Data columns (total 51 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ACC1            6572 non-null   object
#  1   ACC2            6572 non-null   object
#  2   ACC3            6572 non-null   object
#  3   TEMP            6572 non-null   object
#  4   EDA             6572 non-null   object
#  5   BVP             6572 non-null   object
#  6   HR              6572 non-null   object
#  7   Magnitude       6572 non-null   object
#  8   Subject_ID      6572 non-null   object
#  9   Activity        6572 non-null   object
#  10  Round           6572 non-null   int64
#  11  ACC1_mean       6572 non-null   float64
#  12  ACC2_mean       6572 non-null   float64
#  13  ACC3_mean       6572 non-null   float64
#  14  TEMP_mean       6572 non-null   float64
#  15  EDA_mean        6572 non-null   float64
#  16  BVP_mean        6572 non-null   float64
#  17  HR_mean         6572 non-null   float64
#  18  Magnitude_mean  6572 non-null   float64
#  19  ACC1_std        6572 non-null   float64
#  20  ACC2_std        6572 non-null   float64
#  21  ACC3_std        6572 non-null   float64
#  22  TEMP_std        6572 non-null   float64
#  23  EDA_std         6572 non-null   float64
#  24  BVP_std         6572 non-null   float64
#  25  HR_std          6572 non-null   float64
#  26  Magnitude_std   6572 non-null   float64
#  27  ACC1_skew       6510 non-null   float64
#  28  ACC2_skew       6524 non-null   float64
#  29  ACC3_skew       6536 non-null   float64
#  30  TEMP_skew       6572 non-null   float64
#  31  EDA_skew        6572 non-null   float64
#  32  BVP_skew        6572 non-null   float64
#  33  HR_skew         6572 non-null   float64
#  34  Magnitude_skew  6572 non-null   float64
#  35  ACC1_min        6572 non-null   float64
#  36  ACC2_min        6572 non-null   float64
#  37  ACC3_min        6572 non-null   float64
#  38  TEMP_min        6572 non-null   float64
#  39  EDA_min         6572 non-null   float64
#  40  BVP_min         6572 non-null   float64
#  41  HR_min          6572 non-null   float64
#  42  Magnitude_min   6572 non-null   float64
#  43  ACC1_max        6572 non-null   float64
#  44  ACC2_max        6572 non-null   float64
#  45  ACC3_max        6572 non-null   float64
#  46  TEMP_max        6572 non-null   float64
#  47  EDA_max         6572 non-null   float64
#  48  BVP_max         6572 non-null   float64
#  49  HR_max          6572 non-null   float64
#  50  Magnitude_max   6572 non-null   float64
# dtypes: float64(40), int64(1), object(10)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#              Round    ACC1_mean    ACC2_mean    ACC3_mean    TEMP_mean  \
# count  6572.000000  6572.000000  6572.000000  6572.000000  6572.000000
# mean      1.481132     6.869465     8.703668    24.576161    33.168642
# std       0.499682    38.834313    38.335837    24.205938     1.265012
# min       1.000000  -110.628571   -85.509303   -76.556164    29.357000
# 25%       1.000000   -29.366843   -11.555704     7.589617    32.290750
# 50%       1.000000    17.756734     6.364547    24.028125    33.369750
# 75%       2.000000    38.437095    31.657924    45.060584    34.137000
# max       2.000000   110.254118    98.046121    92.769737    36.416000
#
#           EDA_mean     BVP_mean      HR_mean  Magnitude_mean     ACC1_std  \
# count  6572.000000  6572.000000  6572.000000     6572.000000  6572.000000
# mean      4.175449     0.016950    86.537271       67.695828     7.910041
# std       8.013829     2.841132    15.314664        8.342834     7.429935
# min       0.006148   -20.568750    48.924188       37.192921     0.000000
# 25%       0.224809    -0.812031    75.829547       62.909324     1.496717
# 50%       1.485549     0.018312    85.185094       65.745502     6.040973
# 75%       4.511118     0.812563    96.834453       71.040676    12.401048
# max      76.624004    32.770500   162.717625      139.950335    58.736502
#
#           ACC2_std     ACC3_std     TEMP_std      EDA_std      BVP_std  \
# count  6572.000000  6572.000000  6572.000000  6572.000000  6572.000000
# mean      9.250891     8.092527     0.022281     0.162469    52.438431
# std      10.520711     8.270658     0.020312     0.246096    52.095039
# min       0.000000     0.000000     0.003000     0.000891     0.498170
# 25%       1.037852     1.447853     0.013266     0.008665    19.666916
# 50%       5.171681     5.612040     0.017059     0.070568    35.979836
# 75%      13.876920    11.891025     0.024833     0.226159    65.564535
# max      63.201619    62.778391     0.770462     3.281518   436.013759
#
#             HR_std  Magnitude_std     ACC1_skew     ACC2_skew     ACC3_skew  \
# count  6572.000000    6572.000000  6.510000e+03  6.524000e+03  6.536000e+03
# mean      1.094109       6.746436 -7.559377e-03 -4.125348e-02 -1.577413e-01
# std       1.043740       6.334428  1.098937e+00  1.111494e+00  1.099679e+00
# min       0.011421       0.001474 -8.775686e+00 -7.254128e+00 -8.268405e+00
# 25%       0.349137       1.090672 -4.068692e-01 -4.417558e-01 -5.814530e-01
# 50%       0.759199       4.902906 -7.881091e-17 -5.964845e-16 -1.905950e-14
# 75%       1.519270      11.298844  4.218040e-01  3.457590e-01  2.268180e-01
# max      10.226556      38.242312  8.775686e+00  8.775686e+00  8.775686e+00
#
#          TEMP_skew     EDA_skew     BVP_skew      HR_skew  Magnitude_skew  \
# count  6572.000000  6572.000000  6572.000000  6572.000000     6572.000000
# mean     -0.026331     0.387768    -0.198833    -0.002717        0.103735
# std       0.609450     0.925768     0.874834     0.626845        1.031014
# min      -3.172502    -5.193445    -5.233724    -2.787084       -7.763299
# 25%      -0.367745    -0.088061    -0.562751    -0.373594       -0.286297
# 50%      -0.011149     0.343242    -0.213405     0.002028        0.040909
# 75%       0.318422     0.884710     0.190516     0.360047        0.462464
# max       3.181184     8.706911     5.419461     2.735236        8.774836
#
#           ACC1_min     ACC2_min     ACC3_min     TEMP_min      EDA_min  \
# count  6572.000000  6572.000000  6572.000000  6572.000000  6572.000000
# mean    -12.403306   -11.704735     4.274566    33.129308     3.889613
# std      44.598008    41.702483    35.761606     1.265297     7.723457
# min    -128.000000  -128.000000  -128.000000    26.650000     0.000000
# 25%     -48.000000   -35.000000   -18.000000    32.250000     0.189546
# 50%      -6.000000    -6.000000     1.317387    33.330000     1.236324
# 75%      21.881962    16.000000    35.053565    34.110000     4.139333
# max     106.164706    92.000000    76.035897    36.390000    75.600563
#
#            BVP_min       HR_min  Magnitude_min     ACC1_max     ACC2_max  \
# count  6572.000000  6572.000000    6572.000000  6572.000000  6572.000000
# mean   -170.549361    84.713631      52.357189    26.285514    28.502354
# std     182.138130    15.117284      13.943277    43.867600    42.722398
# min   -1722.290000    48.200000       6.403124  -100.310204   -83.648276
# 25%    -217.767500    74.295000      43.260836    -8.000000    -1.282710
# 50%    -108.095000    83.400000      54.281673    34.000000    18.972243
# 75%     -52.810000    94.973125      61.822980    59.482843    61.000000
# max      -1.090000   161.530000     135.775088   127.000000   127.000000
#
#           ACC3_max     TEMP_max      EDA_max      BVP_max       HR_max  \
# count  6572.000000  6572.000000  6572.000000  6572.000000  6572.000000
# mean     41.777408    33.206433     4.515464   154.383570    88.365180
# std      27.108530     1.266619     8.305574   165.211018    15.533108
# min     -62.604478    29.570000     0.010246     1.140000    50.020000
# 25%      25.641538    32.330000     0.259985    48.340000    77.423750
# 50%      45.202375    33.410000     1.708956   102.610000    87.230000
# 75%      60.000000    34.160000     4.971825   194.780000    98.538125
# max     127.000000    36.430000    77.247574  1836.170000   163.220000
#
#        Magnitude_max
# count    6572.000000
# mean       84.847394
# std        22.438202
# min        41.556393
# 25%        67.028637
# 50%        78.654307
# 75%        98.228051
# max       214.946505

# %% [markdown]
# ## Initial RF Model

# %%
np.random.seed(29)
rands = np.random.choice(df.Subject_ID.unique(),11, replace=False)
print(rands)
# Out:
# ['19-041' '19-018' '19-047' '19-010' '19-054' '19-008' '19-026' '19-040'
#  '19-011' '19-038' '19-007']

# %% [markdown]
# ### Split Subjects into Test and Train Sets (n=44,11)

# %%
test = df[df['Subject_ID'].isin(rands)] 
train = df[-df['Subject_ID'].isin(rands)]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Run this for Both Accelerometry and Physiological Data

# %%
"""
train = train[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 
        'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std','Activity']]
test = test[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 
        'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'Activity']]
"""
# Out:
# "\ntrain = train[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', \n        'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std','Activity']]\ntest = test[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', \n        'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'Activity']]\n"

# %% [markdown]
# ### Run this for Only Accelerometer Data

# %%
train = train[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std','Magnitude_std','Activity']]
test = test[['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std','Magnitude_std','Activity']]

# %% [markdown]
# ### Run this for only Physiological Data

# %%
"""
train = train[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Activity']]
test = test[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Activity']] 
"""
# Out:
# "\ntrain = train[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Activity']]\ntest = test[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Activity']] \n"

# %% [markdown]
# ### Run for Feature Importances

# %%
"""
train = train[['ACC1_mean', 'ACC2_mean',
       'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean',
       'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'ACC1_skew',
       'ACC2_skew', 'ACC3_skew', 'TEMP_skew', 'EDA_skew', 'BVP_skew',
       'HR_skew', 'Magnitude_skew', 'ACC1_min', 'ACC2_min', 'ACC3_min',
       'TEMP_min', 'EDA_min', 'BVP_min', 'HR_min', 'Magnitude_min', 'ACC1_max',
       'ACC2_max', 'ACC3_max', 'TEMP_max', 'EDA_max', 'BVP_max', 'HR_max',
       'Magnitude_max','Activity']]
test =test[['ACC1_mean', 'ACC2_mean',
       'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean',
       'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'ACC1_skew',
       'ACC2_skew', 'ACC3_skew', 'TEMP_skew', 'EDA_skew', 'BVP_skew',
       'HR_skew', 'Magnitude_skew', 'ACC1_min', 'ACC2_min', 'ACC3_min',
       'TEMP_min', 'EDA_min', 'BVP_min', 'HR_min', 'Magnitude_min', 'ACC1_max',
       'ACC2_max', 'ACC3_max', 'TEMP_max', 'EDA_max', 'BVP_max', 'HR_max',
       'Magnitude_max','Activity']]
"""
# Out:
# "\ntrain = train[['ACC1_mean', 'ACC2_mean',\n       'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean',\n       'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'ACC1_skew',\n       'ACC2_skew', 'ACC3_skew', 'TEMP_skew', 'EDA_skew', 'BVP_skew',\n       'HR_skew', 'Magnitude_skew', 'ACC1_min', 'ACC2_min', 'ACC3_min',\n       'TEMP_min', 'EDA_min', 'BVP_min', 'HR_min', 'Magnitude_min', 'ACC1_max',\n       'ACC2_max', 'ACC3_max', 'TEMP_max', 'EDA_max', 'BVP_max', 'HR_max',\n       'Magnitude_max','Activity']]\ntest =test[['ACC1_mean', 'ACC2_mean',\n       'ACC3_mean', 'TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean',\n       'Magnitude_mean', 'ACC1_std', 'ACC2_std', 'ACC3_std', 'TEMP_std',\n       'EDA_std', 'BVP_std', 'HR_std', 'Magnitude_std', 'ACC1_skew',\n       'ACC2_skew', 'ACC3_skew', 'TEMP_skew', 'EDA_skew', 'BVP_skew',\n       'HR_skew', 'Magnitude_skew', 'ACC1_min', 'ACC2_min', 'ACC3_min',\n       'TEMP_min', 'EDA_min', 'BVP_min', 'HR_min', 'Magnitude_min', 'ACC1_max',\n       'ACC2_max', 'ACC3_max', 'TEMP_max', 'EDA_max', 'BVP_max', 'HR_max',\n       'Magnitude_max','Activity']]\n"

# %% [markdown]
# ## Drop NA Values

# %%
# given the null values present, we must get rid of them (remember earlier function from module 1)

def assess_NA(data):
    # pandas series denoting features and the sum of their null values
    null_sum = data.isnull().sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(data.index))*100).round(2) ).sort_values(ascending=False)

    #concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    return df_NA
print('Before Dropping any Rows:')
assess = assess_NA(train)
assess
# Out:
# Before Dropping any Rows:
#                 Number of NA  Percent NA
# Activity                   0         0.0
# Magnitude_std              0         0.0
# ACC3_std                   0         0.0
# ACC2_std                   0         0.0
# ACC1_std                   0         0.0
# Magnitude_mean             0         0.0
# ACC3_mean                  0         0.0
# ACC2_mean                  0         0.0
# ACC1_mean                  0         0.0

# %%
train=train.dropna()
test = test.dropna()

# %%
train.describe()
# Out:
#          ACC1_mean    ACC2_mean    ACC3_mean  Magnitude_mean     ACC1_std  \
# count  5270.000000  5270.000000  5270.000000     5270.000000  5270.000000
# mean     10.306750    11.616102    24.246818       67.718645     8.170054
# std      37.915357    37.733938    24.267057        8.327061     7.608032
# min    -110.628571   -85.509303   -64.078358       37.192921     0.000000
# 25%     -24.707413    -9.579808     7.316964       62.868731     1.537041
# 50%      21.181390     8.314629    23.811075       65.720745     6.391516
# 75%      40.069994    35.730729    44.585203       71.312602    12.746302
# max      97.743902    98.046121    92.769737      121.533303    58.736502
#
#           ACC2_std     ACC3_std  Magnitude_std
# count  5270.000000  5270.000000    5270.000000
# mean      9.542603     8.252426       7.002194
# std      10.696698     8.339662       6.502737
# min       0.000000     0.000000       0.001474
# 25%       1.075056     1.510781       1.124452
# 50%       5.593296     5.778015       5.258746
# 75%      14.412178    12.053892      11.584727
# max      63.201619    46.538793      38.242312

# %%
test.describe()
# Out:
#          ACC1_mean    ACC2_mean    ACC3_mean  Magnitude_mean     ACC1_std  \
# count  1302.000000  1302.000000  1302.000000     1302.000000  1302.000000
# mean     -7.043357    -3.084756    25.909219       67.603474     6.857611
# std      39.412316    38.506695    23.919899        8.408957     6.558763
# min     -94.998630   -80.571635   -76.556164       46.518199     0.000000
# 25%     -38.249805   -31.592788     8.455521       63.227160     1.363944
# 50%     -21.025000    -0.654606    24.808971       65.843246     4.661798
# 75%      26.917037    22.096856    46.432012       70.323339    11.285748
# max     110.254118    83.006250    74.550926      139.950335    37.245636
#
#           ACC2_std     ACC3_std  Magnitude_std
# count  1302.000000  1302.000000    1302.000000
# mean      8.070156     7.445319       5.711225
# std       9.690618     7.955600       5.483426
# min       0.000000     0.000000       0.002025
# 25%       1.005190     1.159324       0.960205
# 50%       3.308869     5.032527       3.568668
# 75%      12.268990    11.049889      10.225510
# max      47.922800    62.778391      36.884782

# %% [markdown]
# ### Test-Train Split

# %%
X_train = train.iloc[:, :-1].values
y_train = train.iloc[:, -1].values
X_test = test.iloc[:, :-1].values
y_test = test.iloc[:, -1].values

# %% [markdown]
# ### Standardize Data

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### RF Object Initialization

# %%
clf = RandomForestClassifier(n_estimators=750,
random_state=29,
max_depth=25,
min_samples_leaf=1, verbose=1,class_weight='balanced_subsample')

# %% [markdown]
# ### Fit and Predict using RF model

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed:    6.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed:    0.2s finished

# %% [markdown]
# ### Confusion Matrix

# %%
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Confusion matrix, without normalization
# [[518  82   6   3]
#  [ 28 384  28  43]
#  [  1  58  46   0]
#  [  2  46   0  57]]
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed:    0.2s finished
# Normalized confusion matrix
# [[0.85 0.13 0.01 0.  ]
#  [0.06 0.8  0.06 0.09]
#  [0.01 0.55 0.44 0.  ]
#  [0.02 0.44 0.   0.54]]

# %% [markdown]
# ### Evaluate Accuracy & F1 Score

# %%
scores = pd.DataFrame([accuracy_score(y_test, y_pred),f1_score(y_test, y_pred,average='weighted')], columns = ['Score'], index = ['Accuracy', 'F1'])

# %%
scores
# Out:
#              Score
# Accuracy  0.771889
# F1        0.773331

# %% [markdown]
# ### Feature Importances

# %%
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print(str(f+1)+ ". "+train.columns[f] + " (Importance: " + str(importances[indices[f]])+")")
# Out:
# Feature ranking:
# 1. ACC1_mean (Importance: 0.23095673260387958)
# 2. ACC2_mean (Importance: 0.15460227187174336)
# 3. ACC3_mean (Importance: 0.14714108727121958)
# 4. Magnitude_mean (Importance: 0.10537623256911804)
# 5. ACC1_std (Importance: 0.10263431768449666)
# 6. ACC2_std (Importance: 0.10227842475793199)
# 7. ACC3_std (Importance: 0.08421096614336786)
# 8. Magnitude_std (Importance: 0.07279996709824306)

# %%
train.columns[:-1]
# Out:
# Index(['ACC1_mean', 'ACC2_mean', 'ACC3_mean', 'Magnitude_mean', 'ACC1_std',
#        'ACC2_std', 'ACC3_std', 'Magnitude_std'],
#       dtype='object')

# %%
importances = pd.DataFrame(list(zip(train.columns[:-1],clf.feature_importances_)) , columns = ['Feature', 'Importance'])

# %%
importances.sort_values(by='Importance', ascending = False).head()
# Out:
#          Feature  Importance
# 2      ACC3_mean    0.230957
# 1      ACC2_mean    0.154602
# 7  Magnitude_std    0.147141
# 0      ACC1_mean    0.105376
# 5       ACC2_std    0.102634

# %% [markdown]
# ## LOOCV

# %% [markdown]
# __Leave One Out CV:__
# Each observation is considered as a validation set and the rest n-1 observations are a training set. Fit the model and predict using 1 observation validation set. Repeat this for n times for each observation as a validation set.
# Test-error rate is average of all n errors.
#
# __Advantages:__ takes care of both drawbacks of validation-set method
# 1. No randomness of using some observations for training vs. validation set like in validation-set method as each observation is considered for both training a›nd validation. So overall less variability than Validation-set method due to no randomness no matter how many times you run it.
# 2. Less bias than validation-set method as training-set is of n-1 size. Because of this reduced bias, reduced over-estimation of test-error, not as much compared to validation-set method.
#
# __Disadvantages:__
# 1. Even though each iterations test-error is un-biased, it has a high variability as only one-observation validation-set was used for prediction.
# 2. Computationally expensive (time and power) especially if dataset is big with large n as it requires fitting the model n times. Also some statistical models have computationally intensive fitting so with large dataset and these models LOOCV might not be a good choice.

# %% [markdown]
# ### Initialize Loop Iterator & Lists

# %%
subject_ids = list(df.Subject_ID.unique())

# %%
LOOCV_accuracy = []
LOOCV_f1 = []
y_preds = []
y_tests = []

# %% [markdown]
# ### Cross-Validation Algorithm

# %%
for subject in subject_ids:
    
    #Split into test and train based on subject
    test = df.loc[df['Subject_ID']==subject]
    train = df.loc[df['Subject_ID']!=subject]
    
    #Feature selection
    train = train[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Activity']]
    test = test[['TEMP_mean', 'EDA_mean', 'BVP_mean', 'HR_mean', 'TEMP_std',
       'EDA_std', 'BVP_std', 'HR_std', 'Activity']]   
    
    #Test-train split
    X_train = train.iloc[:, :-1].values
    y_train = train.iloc[:, -1].values
    X_test = test.iloc[:, :-1].values
    y_test = test.iloc[:, -1].values
    
    #Standardize data
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    #Random Forest model
    clf = RandomForestClassifier(n_estimators=750,
    random_state=1337,
    max_depth=25,
    min_samples_leaf=1, class_weight='balanced_subsample' )
    
    #Fit and Predict using RF model
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    y_preds.append(y_pred)
    y_tests.append(y_test)
    #Print Accuracy Score
    print('Completed LOOCV for Subject '+ subject)
    
    #Add to Lists
    LOOCV_accuracy.append(accuracy_score(y_test, y_pred))
    LOOCV_f1.append(f1_score(y_test, y_pred,average='weighted'))
# Out:
# Completed LOOCV for Subject 19-001
# Completed LOOCV for Subject 19-002
# Completed LOOCV for Subject 19-003
# Completed LOOCV for Subject 19-004
# Completed LOOCV for Subject 19-005
# Completed LOOCV for Subject 19-006
# Completed LOOCV for Subject 19-007
# Completed LOOCV for Subject 19-008
# Completed LOOCV for Subject 19-009
# Completed LOOCV for Subject 19-010
# Completed LOOCV for Subject 19-011
# Completed LOOCV for Subject 19-012
# Completed LOOCV for Subject 19-013
# Completed LOOCV for Subject 19-014
# Completed LOOCV for Subject 19-015
# Completed LOOCV for Subject 19-016
# Completed LOOCV for Subject 19-017
# Completed LOOCV for Subject 19-018
# Completed LOOCV for Subject 19-019
# Completed LOOCV for Subject 19-020
# Completed LOOCV for Subject 19-021
# Completed LOOCV for Subject 19-022
# Completed LOOCV for Subject 19-023
# Completed LOOCV for Subject 19-024
# Completed LOOCV for Subject 19-025
# Completed LOOCV for Subject 19-026
# Completed LOOCV for Subject 19-027
# Completed LOOCV for Subject 19-029
# Completed LOOCV for Subject 19-030
# Completed LOOCV for Subject 19-031
# Completed LOOCV for Subject 19-032
# Completed LOOCV for Subject 19-033
# Completed LOOCV for Subject 19-034
# Completed LOOCV for Subject 19-035
# Completed LOOCV for Subject 19-036
# Completed LOOCV for Subject 19-037
# Completed LOOCV for Subject 19-038
# Completed LOOCV for Subject 19-039
# Completed LOOCV for Subject 19-040
# Completed LOOCV for Subject 19-041
# Completed LOOCV for Subject 19-042
# Completed LOOCV for Subject 19-043
# Completed LOOCV for Subject 19-044
# Completed LOOCV for Subject 19-045
# Completed LOOCV for Subject 19-046
# Completed LOOCV for Subject 19-047
# Completed LOOCV for Subject 19-048
# Completed LOOCV for Subject 19-049
# Completed LOOCV for Subject 19-050
# Completed LOOCV for Subject 19-051
# Completed LOOCV for Subject 19-052
# Completed LOOCV for Subject 19-053
# Completed LOOCV for Subject 19-054
# Completed LOOCV for Subject 19-055
# Completed LOOCV for Subject 19-056

# %% [markdown]
# ### LOOCV Confusion Matrix

# %%
y_tests.shape
# Out:
# (6572,)

# %%
y_tests = np.concatenate(y_tests, axis=0)
np.shape(y_tests)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-1efac3f8a9f9> in <module>
# ----> 1 y_tests = np.concatenate(y_tests, axis=0)
#       2 np.shape(y_tests)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
y_preds = np.concatenate(y_preds, axis = 0)
np.shape(y_preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-3701d4c3663a> in <module>
# ----> 1 y_preds = np.concatenate(y_preds, axis = 0)
#       2 np.shape(y_preds)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
cm = confusion_matrix(y_tests,y_preds)
cm
# Out:
# array([[2137,  844,   32,   61],
#        [ 988, 1361,   68,   21],
#        [ 179,  309,   39,    3],
#        [ 280,  195,    0,   55]])

# %%
cm= cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
cm
# Out:
# array([[0.7 , 0.27, 0.01, 0.02],
#        [0.41, 0.56, 0.03, 0.01],
#        [0.34, 0.58, 0.07, 0.01],
#        [0.53, 0.37, 0.  , 0.1 ]])

# %%
ax = plt.subplot()
sns.heatmap(cm, annot = True, fmt = '.2f',cmap = 'Blues', xticklabels = ['Activity', 'Baseline', 'DB', 'Typing'], yticklabels = ['Activity', 'Baseline', 'DB', 'Typing'])
ax.set_xlabel("Predicted labels")
ax.set_ylabel('Actual labels')
plt.title('ACC-Only Sensors')
plt.savefig('conf_matrix_acc.png')

# %% [markdown]
# ### Create Dataframes to show Error Metrics

# %%
loocv_df = pd.DataFrame(columns = ['Accuracy Score', 'F1 Score'])

# %%
loocv_df['Accuracy Score'] = LOOCV_accuracy 
loocv_df['F1 Score'] = LOOCV_f1

# %%
loocv_df.index = subject_ids

# %%
loocv_df.sort_values(by='F1 Score', ascending = True).head()
# Out:
#         Accuracy Score  F1 Score
# 19-018        0.258065  0.201519
# 19-005        0.266129  0.235294
# 19-030        0.354839  0.294061
# 19-040        0.419355  0.300095
# 19-035        0.330645  0.300658

# %% [markdown]
# ## Results

# %%
results = loocv_df.describe()
results.loc[['mean','std']]
# Out:
#       Accuracy Score  F1 Score
# mean        0.545455  0.498986
# std         0.131970  0.136832

# %%
sns.distplot(loocv_df['Accuracy Score'], rug=True, bins=10)

# %%
sns.distplot(loocv_df['F1 Score'], rug=True,bins=20)
